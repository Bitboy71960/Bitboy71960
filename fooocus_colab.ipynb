seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.23 seconds
#   3% 1/30 [00:01<00:56,  1.94s/it]
# User stopped
# [Fooocus] Processing enhance ...
# Processing time (total): 3.17 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 5.37 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.78 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 4301562597717718903
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] "Ultra realistic portrait of a beautiful young woman, natural blonde hair with subtle highlights, light freckles scattered across her nose and cheeks, captivating bright blue eyes with realistic eyelashes and subtle imperfections, soft natural makeup enhancing her features, slightly asymmetrical facial structure for realism, faint skin texture with pores and fine lines, delicate eyebrows with slight variations, natural skin tone with subtle redness around the nose and cheeks, soft shadows and lighting for depth, cinematic photography style, ultra-detailed skin rendering, hyper-realistic human flaws, 8k resolution, DSLR quality, professional studio lighting with soft diffusion, detailed, elegant, intricate, rich colors, highly contrasted, deep vibrant scenic background, very inspirational, handsome, creative, positive
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] "Ultra realistic portrait of a beautiful young woman, natural blonde hair with subtle highlights, light freckles scattered across her nose and cheeks, captivating bright blue eyes with realistic eyelashes and subtle imperfections, soft natural makeup enhancing her features, slightly asymmetrical facial structure for realism, faint skin texture with pores and fine lines, delicate eyebrows with slight variations, natural skin tone with subtle redness around the nose and cheeks, soft shadows and lighting for depth, cinematic photography style, ultra-detailed skin rendering, hyper-realistic human flaws, 8k resolution, DSLR quality, professional studio lighting with soft diffusion, atmosphere, radiant, rich colors, intricate, very coherent, deep, stunning, inspiring, attractive, full detailed, generous
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Vary] Image is resized because it is too small.
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.87 seconds
# Final resolution is (1024, 1024).
# [Parameters] Denoising Strength = 0.85
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 128])
# Preparation time: 4.37 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 7.754775524139404
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.56 seconds
# 100% 30/30 [00:30<00:00,  1.02s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-27/log.html
# Generating and saving time: 34.23 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 7.754775524139404
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.62 seconds
# 100% 30/30 [00:29<00:00,  1.00it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-27/log.html
# Generating and saving time: 33.52 seconds
# [Fooocus] Processing enhance ...
# [Fooocus] Preparing enhancement 1/2 ...
# [Enhance] Searching for ""
# Downloading: "https://github.com/IDEA-Research/GroundingDINO/releases/download/v0.1.0-alpha/groundingdino_swint_ogc.pth" to /content/Fooocus/models/inpaint/groundingdino_swint_ogc.pth
#
# 100% 662M/662M [00:18<00:00, 37.4MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# final text_encoder_type: bert-base-uncased
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 342kB/s]
# config.json: 100% 570/570 [00:00<00:00, 4.08MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 1.01MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 2.15MB/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors: 100% 440M/440M [00:01<00:00, 227MB/s]
# Requested to load GroundingDINO
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.53 seconds
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:1060: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/groundingdino/models/GroundingDINO/transformer.py:862: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/sam_vit_b_01ec64.pth" to /content/Fooocus/models/sam/sam_vit_b_01ec64.pth
#
# Traceback (most recent call last):
#   File "/content/Fooocus/modules/async_worker.py", line 1471, in worker
#     handler(task)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/async_worker.py", line 1372, in handler
#     mask, dino_detection_count, sam_detection_count, sam_detection_on_mask_count = generate_mask_from_image(
#                                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/extras/inpaint_mask.py", line 83, in generate_mask_from_image
#     sam_checkpoint = modules.config.download_sam_model(sam_options.model_type)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/config.py", line 964, in download_sam_model
#     return downloading_sam_vit_b()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Fooocus/modules/config.py", line 974, in downloading_sam_vit_b
#     load_file_from_url(
#   File "/content/Fooocus/modules/model_loader.py", line 27, in load_file_from_url
#     download_url_to_file(url, cached_file, progress=progress)
#   File "/usr/local/lib/python3.11/dist-packages/torch/hub.py", line 708, in download_url_to_file
#     u = urlopen(req)
#         ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 216, in urlopen
#     return opener.open(url, data, timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 525, in open
#     response = meth(req, response)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 634, in http_response
#     response = self.parent.error(
#                ^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 563, in error
#     return self._call_chain(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 496, in _call_chain
#     result = func(*args)
#              ^^^^^^^^^^^
#   File "/usr/lib/python3.11/urllib/request.py", line 643, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 502: Bad Gateway
# Total time: 135.94 seconds
